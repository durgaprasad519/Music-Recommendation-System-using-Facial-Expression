# %%
import os  
import numpy as np 
import cv2 
from tensorflow.keras.utils import to_categorical

from keras.layers import Input, Dense 
from keras.models import Model
 
is_init = False
size = -1

label = []
dictionary = {}
c = 0

for i in os.listdir():
	if i.split(".")[-1] == "npy" and not(i.split(".")[0] == "labels"):  
		if not(is_init):
			is_init = True 
			X = np.load(i)
			size = X.shape[0]
			y = np.array([i.split('.')[0]]*size).reshape(-1,1)
		else:
			X = np.concatenate((X, np.load(i)))
			y = np.concatenate((y, np.array([i.split('.')[0]]*size).reshape(-1,1)))

		label.append(i.split('.')[0])
		dictionary[i.split('.')[0]] = c  
		c = c+1


for i in range(y.shape[0]):
	y[i, 0] = dictionary[y[i, 0]]
y = np.array(y, dtype="int32")

###  hello = 0 nope = 1 ---> [1,0] ... [0,1]

y = to_categorical(y)

X_new = X.copy()
y_new = y.copy()
counter = 0 

cnt = np.arange(X.shape[0])
np.random.shuffle(cnt)

for i in cnt: 
	X_new[counter] = X[i]
	y_new[counter] = y[i]
	counter = counter + 1


ip = Input(shape=(X.shape[1]))

m = Dense(512, activation="relu")(ip)
m = Dense(256, activation="relu")(m)

op = Dense(y.shape[1], activation="softmax")(m) 

model = Model(inputs=ip, outputs=op)

model.compile(optimizer='rmsprop', loss="categorical_crossentropy", metrics=['acc'])

model.fit(X, y, epochs=50)


model.save("model.h5")
np.save("labels.npy", np.array(label))
# Out:
# Epoch 1/50
# 13/13 [==============================] - 1s 5ms/step - loss: 1.3475 - acc: 0.3075
# Epoch 2/50
# 13/13 [==============================] - 0s 5ms/step - loss: 1.1841 - acc: 0.4975
# Epoch 3/50
# 13/13 [==============================] - 0s 5ms/step - loss: 1.0346 - acc: 0.4925
# Epoch 4/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.9126 - acc: 0.5875
# Epoch 5/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.8409 - acc: 0.6000
# Epoch 6/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.8185 - acc: 0.5925
# Epoch 7/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.7411 - acc: 0.6950
# Epoch 8/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.7023 - acc: 0.7000
# Epoch 9/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6526 - acc: 0.7200
# Epoch 10/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6721 - acc: 0.7225
# Epoch 11/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5633 - acc: 0.7775
# Epoch 12/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5968 - acc: 0.7550
# Epoch 13/50
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5193 - acc: 0.7775
# Epoch 14/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5757 - acc: 0.7450
# Epoch 15/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5345 - acc: 0.7725
# Epoch 16/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4887 - acc: 0.7850
# Epoch 17/50
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5570 - acc: 0.7575
# Epoch 18/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4928 - acc: 0.7825
# Epoch 19/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5378 - acc: 0.7700
# Epoch 20/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4349 - acc: 0.8250
# Epoch 21/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5137 - acc: 0.7600
# Epoch 22/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4719 - acc: 0.7775
# Epoch 23/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4645 - acc: 0.8075
# Epoch 24/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4282 - acc: 0.8025
# Epoch 25/50
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4664 - acc: 0.8025
# Epoch 26/50
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4602 - acc: 0.8025
# Epoch 27/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4199 - acc: 0.8275
# Epoch 28/50
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4840 - acc: 0.8025
# Epoch 29/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4377 - acc: 0.8150
# Epoch 30/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4005 - acc: 0.8125
# Epoch 31/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4652 - acc: 0.7650
# Epoch 32/50
# 13/13 [==============================] - 0s 7ms/step - loss: 0.3799 - acc: 0.8325
# Epoch 33/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3921 - acc: 0.8250
# Epoch 34/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3989 - acc: 0.8150
# Epoch 35/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4198 - acc: 0.8025
# Epoch 36/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4126 - acc: 0.7975
# Epoch 37/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3883 - acc: 0.8350
# Epoch 38/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4147 - acc: 0.8225
# Epoch 39/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3772 - acc: 0.8400
# Epoch 40/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3867 - acc: 0.8200
# Epoch 41/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3495 - acc: 0.8475
# Epoch 42/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3947 - acc: 0.8100
# Epoch 43/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3710 - acc: 0.8500
# Epoch 44/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3544 - acc: 0.8425
# Epoch 45/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3456 - acc: 0.8325
# Epoch 46/50
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3316 - acc: 0.8525
# Epoch 47/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3947 - acc: 0.8100
# Epoch 48/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3305 - acc: 0.8500
# Epoch 49/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3437 - acc: 0.8475
# Epoch 50/50
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3166 - acc: 0.8650
